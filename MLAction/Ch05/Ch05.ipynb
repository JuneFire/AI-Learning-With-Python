# %%
import logRegres
dataArr, lableMat = logRegres.loadDataSet()
weights = logRegres.gradAscent(dataArr, lableMat)
logRegres.plotBestFit(weights.getA())

# %%
from numpy import *
dataArr, lableMat = logRegres.loadDataSet()
weights = logRegres.stocGradAscent0(dataArr, lableMat)
logRegres.plotBestFit(weights)

# %%
dataArr, lableMat = logRegres.loadDataSet()
weights = logRegres.stocGradAscent1(dataArr, lableMat)
logRegres.plotBestFit(weights)
